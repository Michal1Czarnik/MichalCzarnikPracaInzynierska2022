# %% [markdown]
# # 1. Import bibliotek

# %%
#biblioteki
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from os import abort
from scipy import interpolate
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import precision_recall_curve
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import precision_recall_curve
from sklearn.model_selection import learning_curve

# %% [markdown]
# # 2. Import danych

# %%
#import danych z pliku csv, w którym kolumny danych są rozdzielone przecinkami
data_pandas = pd.read_csv(r'/Users/michalczarnik/Git_Project/Praca_dyplomowa/data/data_all.csv', sep=',')

#sprawdzenie czy gdzieś w danych znajduje się wartość null
null_url = pd.isnull(data_pandas["URL"])
null_label = pd.isnull(data_pandas["label"])
if (data_pandas[null_url]).empty and (data_pandas[null_label]).empty:
    print('Dane są okej.')
else:
    print('Błędne dane wejściowe.')
    abort()

#podsumowanie danych
print('\nŁącznie ' + str(data_pandas.count()) + ' rekordów.')
print('\nPodsumowanie danych z uwzględnieniem etykiet:')
data_pandas.groupby("label").count()
# Out:
# Dane są okej.
#
# Łącznie URL      441263
# label    441263
# dtype: int64 rekordów.
#
# Podsumowanie danych z uwzględnieniem etykiet:
#           URL
# label
# 0      354821
# 1       86442

# %% [markdown]
# # 3. Obróbka danych

# %%
#tokenizer
def token(f):
    slash = str(f.encode('utf-8')).split('/')
    total = []
    for i in slash:
        tokens = str(i).split('-')
        dot = []
        for j in range(0, len(tokens)):
            temp = str(tokens[j]).split('.')
            dot += temp
        total += tokens + dot
    total = list(set(total))
    return total

pandas_URL = data_pandas['URL']
pandas_label = data_pandas['label']
tfidf_pandas = TfidfVectorizer(tokenizer = token)
tfidf_URL = tfidf_pandas.fit_transform(pandas_URL)

# %% [markdown]
# # 4. Podział danych

# %%
#podział danych
URL_train, URL_test, label_train, label_test = train_test_split(tfidf_URL, pandas_label, test_size=0.33)

#podsumowanie danych po podzieleniu na treningowe i testowe
if ((URL_train.shape[0] == label_train.shape[0]) & (URL_test.shape[0] == label_test.shape[0])):
    print('\nŁącznie ' + str(URL_train.shape[0]) + ' treningowych rekordów.')
    print('Łącznie ' + str(URL_test.shape[0]) + 'testowych rekordów.')
else:
    print('Coś poszło nie tak')
    abort()

#wyświetlenie przykładowych adresów URL przedstawionych jako wektory cech
print('\nWektory cech dla procesu trenowania modelu:')
print(URL_train)
# Out:
# Łącznie 295646 treningowych rekordów.
# Łącznie 145617testowych rekordów.
#
# Wektory cech dla procesu trenowania modelu:
#   (0, 347752)	0.42443397749168743
#   (0, 347751)	0.42443397749168743
#   (0, 40065)	0.27143803731797694
#   (0, 504402)	0.2612547249975541
#   (0, 468269)	0.2848380019928601
#   (0, 468268)	0.2697687321643395
#   (0, 497513)	0.28233080472567756
#   (0, 467326)	0.31193556065601724
#   (0, 422814)	0.21209072244027422
#   (0, 129605)	0.2800063724190283
#   (0, 483443)	0.20406186087201167
#   (0, 444707)	0.04277076489691548
#   (1, 56300)	0.3312247659978883
#   (1, 131086)	0.3920831555220368
#   (1, 659194)	0.39337747183125715
#   (1, 131081)	0.36847587053359726
#   (1, 659193)	0.39337747183125715
#   (1, 44192)	0.34793080095717893
#   (1, 79209)	0.33849089553324063
#   (1, 483443)	0.23592983507333679
#   (2, 478501)	0.5882244002058409
#   (2, 223579)	0.5702974637524295
#   (2, 223578)	0.5702974637524295
#   (2, 444707)	0.05927613919252231
#   (3, 554431)	0.40725632906938186
#   :	:
#   (295642, 246266)	0.3376015435742352
#   (295642, 711140)	0.39497140950675663
#   (295642, 1738)	0.1361690011041692
#   (295642, 444707)	0.07749127982030829
#   (295643, 410652)	0.5443395252181683
#   (295643, 410651)	0.5443395252181683
#   (295643, 217521)	0.44100008234374505
#   (295643, 217522)	0.44100008234374505
#   (295643, 521545)	0.12416874644871338
#   (295643, 444707)	0.05485380316343983
#   (295644, 135317)	0.39243242736109024
#   (295644, 615190)	0.39243242736109024
#   (295644, 135318)	0.39243242736109024
#   (295644, 615189)	0.39243242736109024
#   (295644, 515492)	0.344959209511393
#   (295644, 78436)	0.2639235947809439
#   (295644, 78435)	0.2635478346840475
#   (295644, 549563)	0.2639235947809439
#   (295644, 130320)	0.1969461388132471
#   (295644, 601356)	0.12597560370535704
#   (295644, 444707)	0.03954592699618584
#   (295645, 734544)	0.8820244760569456
#   (295645, 398895)	0.3271945497798122
#   (295645, 398896)	0.3272253137885674
#   (295645, 444707)	0.08888275562126863

# %% [markdown]
# # 5. Definicja przydatnych parametrów

# %%
def WYKRESY(model, y_actual, y_predict, URL_train, label_train):
    cm = confusion_matrix(y_actual, y_predict)

    FP = cm.sum(axis=0) - np.diag(cm)  
    FN = cm.sum(axis=1) - np.diag(cm)
    TP = np.diag(cm)
    TN = cm.sum() - (FP + FN + TP)

    print('Prawdziwie pozytywne: %s' % TP[0])
    print('Prawdziwie negatywne: %s' % TN[0])
    print('Fałszywie pozytywne: %s' % FP[0])
    print('Fałszywie negatywne: %s' % FN[0])
    czulosc = (TP[0]) / (TP[0] + FN[0])
    specyficznosc = (TN[0]) / (TN[0] + FP[0])
    dokladnosc = (TP[0] + TN[0]) / (TP[0] + TN[0] + FP[0] + FN[0])
    zr_dokladnosc = (czulosc + specyficznosc) / 2
    print('Reprezentacja czułości: %s' % czulosc)
    print('Specyficzność: %s' % specyficznosc)
    print('Dokładność: %s' % dokladnosc)
    print('Zrównoważona dokładność: %s' % zr_dokladnosc)

    horizontal = ["Adres bezpieczny", "Phishing"]
    vertical = ["0", "1"]
    data = ([[TP[0], FP[0]],
                 [FN[0], TN[0]]])

    #kontur wykresu
    fig, ax = plt.subplots()
    im = ax.imshow(data)
    ax.set_xticks(np.arange(len(horizontal)))
    ax.set_yticks(np.arange(len(vertical)))
    ax.set_xticklabels(horizontal)
    ax.set_yticklabels(vertical)

    #naniesienie danych na wykres
    for i in range(len(horizontal)):
        for j in range(len(vertical)):
            text = ax.text(j, i, data[i][j], ha = "center", va = "center")
    ax.set_title("Tablica pomyłek")
    fig.tight_layout()
    plt.show()

    TPR = czulosc
    FPR = 1 - specyficznosc
    
    x = np.array([0, FPR, 1])
    y = np.array([0, TPR, 1])

    AUC = np.trapz(y, x)
    print('AUC = %s' % AUC)
    plt.figure(1)
    plt.plot(x, y, 'r')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.xlabel('FPR')
    plt.ylabel('TPR')
    plt.title('Charakterystyka ROC')
    
    precision, recall, thresholds = precision_recall_curve(y_actual, y_predict)
    plt.figure(2)
    plt.plot(recall, precision, 'r')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.xlabel('przypomnienie')
    plt.ylabel('precyzja')
    plt.title('Charakterystyka precyzja-przypomnienie')

# %% [markdown]
# # 6. Implementacja algorytmu drzewa decyzyjnego do grafu

# %%
#stworzenie modelu
decision_tree = DecisionTreeClassifier(criterion = 'gini')

#wytrenowanie modelu
decision_tree_trained = decision_tree.fit(URL_train, label_train)

y_actual_DT = label_test
y_predict_DT = decision_tree.predict(URL_test)

WYKRESY(decision_tree, y_actual_DT, y_predict_DT, URL_train, label_train)
# Out:
# Prawdziwie pozytywne: 115606
# Prawdziwie negatywne: 24767
# Fałszywie pozytywne: 3528
# Fałszywie negatywne: 1716
# Reprezentacja czułości: 0.9853735872214929
# Specyficzność: 0.8753136596571832
# Dokładność: 0.9639877212138692
# Zrównoważona dokładność: 0.9303436234393381
# AUC = 0.930343623439338

# %%
from sklearn.tree import plot_tree

# %%
import sys
sys.setrecursionlimit(10000)

# %%
plot_tree(decision_tree_trained)
# Out:
# [Text(321.5991192285466, 217.36708249496982, 'X[0] <= 0.024\ngini = 0.316\nsamples = 295646\nvalue = [237499, 58147]'),
#  Text(309.0584505138844, 217.22124748490944, 'X[749649] <= 0.037\ngini = 0.287\nsamples = 284533\nvalue = [235069, 49464]'),
#  Text(290.60884589765044, 217.0754124748491, 'X[628638] <= 0.079\ngini = 0.267\nsamples = 279405\nvalue = [235007, 44398]'),
#  Text(264.09373447981994, 216.92957746478874, 'X[444707] <= 0.03\ngini = 0.241\nsamples = 270006\nvalue = [232256, 37750]'),
#  Text(228.1066848368547, 216.78374245472835, 'X[615810] <= 0.07\ngini = 0.365\nsamples = 76285\nvalue = [57976, 18309]'),
#  Text(223.42235013811975, 216.637907444668, 'X[424110] <= 0.043\ngini = 0.44\nsamples = 51573\nvalue = [34707, 16866]'),
#  Text(219.43690489273456, 216.49207243460765, 'X[476348] <= 0.111\ngini = 0.466\nsamples = 45077\nvalue = [28441, 16636]'),
#  Text(212.6211739853118, 216.34623742454727, 'X[601356] <= 0.092\ngini = 0.484\nsamples = 40362\nvalue = [23814, 16548]'),
#  Text(207.10653433193585, 216.20040241448692, 'X[444961] <= 0.234\ngini = 0.498\nsamples = 30966\nvalue = [16533, 14433]'),
#  Text(204.9674503232343, 216.05456740442656, 'X[506759] <= 0.127\ngini = 0.499\nsamples = 26758\nvalue = [12886, 13872]'),
#  Text(202.67471283970988, 215.90873239436618, 'X[720530] <= 0.043\ngini = 0.493\nsamples = 24814\nvalue = [10990, 13824]'),
#  Text(200.88688998858103, 215.76289738430583, 'X[596814] <= 0.131\ngini = 0.474\nsamples = 21752\nvalue = [8386, 13366]'),
#  Text(200.0727976652637, 215.61706237424548, 'X[723330] <= 0.137\ngini = 0.467\nsamples = 21270\nvalue = [7905, 13365]'),
#  Text(198.8777978623844, 215.4712273641851, 'X[444707] <= 0.021\ngini = 0.457\nsamples = 20373\nvalue = [7183, 13190]'),
#  Text(197.7151553139326, 215.32539235412474, 'X[601399] <= 0.342\ngini = 0.446\nsamples = 19605\nvalue = [6589, 13016]'),
#  Text(196.47283232641738, 215.1795573440644, 'X[670229] <= 0.167\ngini = 0.44\nsamples = 19321\nvalue = [6321, 13000]'),
#  Text(195.14334593473453, 215.033722334004, 'X[443096] <= 0.227\ngini = 0.452\nsamples = 18117\nvalue = [6252, 11865]'),
#  Text(194.0727175784718, 214.88788732394366, 'X[615821] <= 0.392\ngini = 0.446\nsamples = 17783\nvalue = [5969, 11814]'),
#  Text(192.65343560553862, 214.7420523138833, 'X[718591] <= 0.065\ngini = 0.441\nsamples = 17597\nvalue = [5785, 11812]'),
#  Text(190.53684639926448, 214.59621730382293, 'X[670237] <= 0.378\ngini = 0.436\nsamples = 17379\nvalue = [5591, 11788]'),
#  Text(187.02564272630843, 214.45038229376257, 'X[520331] <= 0.064\ngini = 0.432\nsamples = 17196\nvalue = [5419, 11777]'),
#  Text(181.37498738562164, 214.30454728370222, 'X[549424] <= 0.343\ngini = 0.421\nsamples = 16392\nvalue = [4934, 11458]'),
#  Text(181.2305924377032, 214.15871227364184, 'X[537447] <= 0.154\ngini = 0.417\nsamples = 16271\nvalue = [4813, 11458]'),
#  Text(176.72148473614985, 214.0128772635815, 'X[587202] <= 0.092\ngini = 0.402\nsamples = 15016\nvalue = [4183, 10833]'),
#  Text(176.5770897882314, 213.86704225352113, 'X[521545] <= 0.072\ngini = 0.398\nsamples = 14925\nvalue = [4092, 10833]'),
#  Text(173.86600058678138, 213.72120724346075, 'X[442928] <= 0.324\ngini = 0.382\nsamples = 13645\nvalue = [3509, 10136]'),
#  Text(173.7216056388629, 213.5753722334004, 'X[539718] <= 0.177\ngini = 0.378\nsamples = 13565\nvalue = [3429, 10136]'),
#  Text(173.57721069094447, 213.42953722334005, 'X[495234] <= 0.323\ngini = 0.374\nsamples = 13488\nvalue = [3352, 10136]'),
#  Text(172.83094681243486, 213.28370221327967, 'X[530024] <= 0.345\ngini = 0.369\nsamples = 13409\nvalue = [3274, 10135]'),
#  Text(171.77160389917097, 213.13786720321932, 'X[459591] <= 0.314\ngini = 0.365\nsamples = 13335\nvalue = [3201, 10134]'),
#  Text(170.08610291639857, 212.99203219315896, 'X[507109] <= 0.225\ngini = 0.36\nsamples = 13258\nvalue = [3127, 10131]'),
#  Text(169.94170796848013, 212.84619718309858, 'X[1738] <= 0.112\ngini = 0.357\nsamples = 13195\nvalue = [3064, 10131]'),
#  Text(167.29268074252758, 212.70036217303823, 'X[476354] <= 0.222\ngini = 0.343\nsamples = 12541\nvalue = [2762, 9779]'),
#  Text(167.14828579460914, 212.55452716297788, 'X[479124] <= 0.108\ngini = 0.339\nsamples = 12480\nvalue = [2701, 9779]'),
#  Text(166.787298424813, 212.4086921529175, 'X[541064] <= 0.373\ngini = 0.334\nsamples = 12377\nvalue = [2618, 9759]'),
#  Text(166.64290347689456, 212.26285714285714, 'X[540083] <= 0.216\ngini = 0.33\nsamples = 12326\nvalue = [2567, 9759]'),
#  Text(166.49850852897612, 212.1170221327968, 'X[663255] <= 0.087\ngini = 0.326\nsamples = 12280\nvalue = [2521, 9759]'),
#  Text(166.35411358105765, 211.9711871227364, 'X[506762] <= 0.394\ngini = 0.323\nsamples = 12235\nvalue = [2476, 9759]'),
#  Text(166.2097186331392, 211.82535211267606, 'X[443100] <= 0.39\ngini = 0.319\nsamples = 12191\nvalue = [2432, 9759]'),
#  Text(166.06532368522076, 211.6795171026157, 'X[718604] <= 0.305\ngini = 0.316\nsamples = 12148\nvalue = [2389, 9759]'),
#  Text(165.92092873730232, 211.53368209255532, 'X[39297] <= 0.04\ngini = 0.313\nsamples = 12106\nvalue = [2347, 9759]'),
#  Text(165.77653378938385, 211.38784708249497, 'X[372113] <= 0.148\ngini = 0.309\nsamples = 12065\nvalue = [2306, 9759]'),
#  Text(165.6321388414654, 211.2420120724346, 'X[424124] <= 0.16\ngini = 0.306\nsamples = 12032\nvalue = [2273, 9759]'),
#  Text(165.48774389354696, 211.09617706237424, 'X[481389] <= 0.4\ngini = 0.304\nsamples = 11999\nvalue = [2240, 9759]'),
#  Text(165.34334894562852, 210.95034205231389, 'X[444961] <= 0.188\ngini = 0.301\nsamples = 11966\nvalue = [2207, 9759]'),
#  Text(164.09173729203187, 210.80450704225353, 'X[130198] <= 0.214\ngini = 0.295\nsamples = 11821\nvalue = [2124, 9697]'),
#  Text(163.94734234411342, 210.65867203219315, 'X[612215] <= 0.045\ngini = 0.292\nsamples = 11788\nvalue = [2091, 9697]'),
#  Text(163.32125335985998, 210.5128370221328, 'X[610238] <= 0.087\ngini = 0.289\nsamples = 11754\nvalue = [2058, 9696]'),
#  Text(162.50226023510845, 210.36700201207242, 'X[430758] <= 0.226\ngini = 0.283\nsamples = 11630\nvalue = [1987, 9643]'),
#  Text(162.35786528718998, 210.22116700201207, 'X[625937] <= 0.14\ngini = 0.281\nsamples = 11604\nvalue = [1961, 9643]'),
#  Text(162.21347033927154, 210.0753319919517, 'X[526441] <= 0.373\ngini = 0.279\nsamples = 11580\nvalue = [1937, 9643]'),
#  Text(162.0690753913531, 209.92949698189133, 'X[713419] <= 0.155\ngini = 0.276\nsamples = 11558\nvalue = [1915, 9643]'),
#  Text(161.92468044343465, 209.78366197183098, 'X[647019] <= 0.281\ngini = 0.274\nsamples = 11537\nvalue = [1894, 9643]'),
#  Text(161.78028549551618, 209.63782696177063, 'X[685839] <= 0.086\ngini = 0.272\nsamples = 11516\nvalue = [1873, 9643]'),
#  Text(161.08086640748306, 209.49199195171025, 'X[711651] <= 0.432\ngini = 0.269\nsamples = 11450\nvalue = [1832, 9618]'),
#  Text(160.93647145956461, 209.3461569416499, 'X[230976] <= 0.383\ngini = 0.267\nsamples = 11431\nvalue = [1813, 9618]'),
#  Text(160.79207651164614, 209.20032193158954, 'X[582913] <= 0.211\ngini = 0.265\nsamples = 11412\nvalue = [1794, 9618]'),
#  Text(160.11521307517214, 209.05448692152916, 'X[730901] <= 0.238\ngini = 0.263\nsamples = 11386\nvalue = [1772, 9614]'),
#  Text(159.9708181272537, 208.9086519114688, 'X[557517] <= 0.345\ngini = 0.261\nsamples = 11370\nvalue = [1756, 9614]'),
#  Text(159.82642317933522, 208.76281690140846, 'X[677720] <= 0.072\ngini = 0.26\nsamples = 11354\nvalue = [1740, 9614]'),
#  Text(159.19467104597945, 208.61698189134808, 'X[441090] <= 0.493\ngini = 0.257\nsamples = 11308\nvalue = [1710, 9598]'),
#  Text(159.05027609806098, 208.47114688128772, 'X[38797] <= 0.054\ngini = 0.255\nsamples = 11292\nvalue = [1694, 9598]'),
#  Text(158.90588115014253, 208.32531187122737, 'X[597467] <= 0.214\ngini = 0.253\nsamples = 11276\nvalue = [1678, 9598]'),
#  Text(158.7614862022241, 208.179476861167, 'X[218129] <= 0.149\ngini = 0.252\nsamples = 11261\nvalue = [1663, 9598]'),
#  Text(158.61709125430565, 208.03364185110664, 'X[114447] <= 0.206\ngini = 0.25\nsamples = 11246\nvalue = [1648, 9598]'),
#  Text(158.47269630638718, 207.88780684104628, 'X[609514] <= 0.382\ngini = 0.249\nsamples = 11231\nvalue = [1633, 9598]'),
#  Text(157.93116677926787, 207.7419718309859, 'X[493081] <= 0.085\ngini = 0.247\nsamples = 11214\nvalue = [1617, 9597]'),
#  Text(157.28129256878455, 207.59613682092555, 'X[719779] <= 0.474\ngini = 0.244\nsamples = 11172\nvalue = [1590, 9582]'),
#  Text(156.70351888741016, 207.4503018108652, 'X[643399] <= 0.425\ngini = 0.242\nsamples = 11156\nvalue = [1575, 9581]'),
#  Text(155.98115636841678, 207.30446680080482, 'X[103057] <= 0.335\ngini = 0.24\nsamples = 11125\nvalue = [1553, 9572]'),
#  Text(155.25840607002223, 207.15863179074447, 'X[413723] <= 0.389\ngini = 0.239\nsamples = 11110\nvalue = [1539, 9571]'),
#  Text(154.24609031698847, 207.0127967806841, 'X[527908] <= 0.104\ngini = 0.237\nsamples = 11093\nvalue = [1524, 9569]'),
#  Text(153.1600259723909, 206.86696177062373, 'X[652798] <= 0.245\ngini = 0.234\nsamples = 11028\nvalue = [1491, 9537]'),
#  Text(153.01563102447247, 206.72112676056338, 'X[715730] <= 0.236\ngini = 0.232\nsamples = 11016\nvalue = [1479, 9537]'),
#  Text(152.25135307748224, 206.57529175050303, 'X[756810] <= 0.173\ngini = 0.231\nsamples = 11000\nvalue = [1465, 9535]'),
#  Text(151.15598202725712, 206.42945674044265, 'X[372875] <= 0.39\ngini = 0.225\nsamples = 10813\nvalue = [1400, 9413]'),
#  Text(151.01158707933865, 206.2836217303823, 'X[479580] <= 0.099\ngini = 0.224\nsamples = 10802\nvalue = [1389, 9413]'),
#  Text(150.8671921314202, 206.13778672032194, 'X[388585] <= 0.181\ngini = 0.223\nsamples = 10791\nvalue = [1378, 9413]'),
#  Text(150.72279718350177, 205.99195171026156, 'X[209465] <= 0.07\ngini = 0.221\nsamples = 10780\nvalue = [1367, 9413]'),
#  Text(150.57840223558333, 205.8461167002012, 'X[594197] <= 0.119\ngini = 0.22\nsamples = 10770\nvalue = [1357, 9413]'),
#  Text(150.43400728766485, 205.70028169014086, 'X[435518] <= 0.419\ngini = 0.219\nsamples = 10760\nvalue = [1347, 9413]'),
#  Text(149.9399058252564, 205.55444668008047, 'X[605519] <= 0.413\ngini = 0.218\nsamples = 10748\nvalue = [1336, 9412]'),
#  Text(149.38488774419488, 205.40861167002012, 'X[443096] <= 0.223\ngini = 0.216\nsamples = 10736\nvalue = [1325, 9411]'),
#  Text(148.70803642582715, 205.26277665995977, 'X[537456] <= 0.4\ngini = 0.214\nsamples = 10705\nvalue = [1306, 9399]'),
#  Text(148.0763085286839, 205.1169416498994, 'X[756596] <= 0.328\ngini = 0.212\nsamples = 10679\nvalue = [1289, 9390]'),
#  Text(147.93191358076547, 204.97110663983904, 'X[687858] <= 0.249\ngini = 0.211\nsamples = 10670\nvalue = [1280, 9390]'),
#  Text(147.78751863284702, 204.82527162977868, 'X[397713] <= 0.152\ngini = 0.21\nsamples = 10661\nvalue = [1271, 9390]'),
#  Text(147.64312368492855, 204.6794366197183, 'X[467965] <= 0.113\ngini = 0.209\nsamples = 10652\nvalue = [1262, 9390]'),
#  Text(147.4987287370101, 204.53360160965795, 'X[408394] <= 0.247\ngini = 0.208\nsamples = 10643\nvalue = [1253, 9390]'),
#  Text(146.95724768231594, 204.38776659959757, 'X[112445] <= 0.05\ngini = 0.206\nsamples = 10630\nvalue = [1242, 9388]'),
#  Text(146.5962603125198, 204.24193158953722, 'X[394916] <= 0.065\ngini = 0.205\nsamples = 10607\nvalue = [1227, 9380]'),
#  Text(146.3074704166829, 204.09609657947686, 'X[135736] <= 0.104\ngini = 0.213\nsamples = 10142\nvalue = [1226, 8916]'),
#  Text(146.16307546876445, 203.9502615694165, 'X[602622] <= 0.221\ngini = 0.22\nsamples = 9726\nvalue = [1226, 8500]'),
#  Text(146.018680520846, 203.80442655935613, 'X[446833] <= 0.236\ngini = 0.219\nsamples = 9718\nvalue = [1218, 8500]'),
#  Text(145.87428557292756, 203.65859154929578, 'X[671388] <= 0.252\ngini = 0.218\nsamples = 9710\nvalue = [1210, 8500]'),
#  Text(145.7298906250091, 203.5127565392354, 'X[105816] <= 0.16\ngini = 0.217\nsamples = 9702\nvalue = [1202, 8500]'),
#  Text(145.58549567709065, 203.36692152917504, 'X[503557] <= 0.26\ngini = 0.216\nsamples = 9694\nvalue = [1194, 8500]'),
#  Text(145.4411007291722, 203.2210865191147, 'X[127351] <= 0.416\ngini = 0.215\nsamples = 9686\nvalue = [1186, 8500]'),
#  Text(145.29670578125376, 203.0752515090543, 'X[114877] <= 0.189\ngini = 0.214\nsamples = 9678\nvalue = [1178, 8500]'),
#  Text(145.1523108333353, 202.92941649899396, 'X[723380] <= 0.43\ngini = 0.213\nsamples = 9670\nvalue = [1170, 8500]'),
#  Text(145.00791588541685, 202.7835814889336, 'X[718847] <= 0.23\ngini = 0.212\nsamples = 9662\nvalue = [1162, 8500]'),
#  Text(144.8635209374984, 202.63774647887323, 'X[677562] <= 0.48\ngini = 0.21\nsamples = 9654\nvalue = [1154, 8500]'),
#  Text(144.71912598957996, 202.49191146881287, 'X[505485] <= 0.408\ngini = 0.209\nsamples = 9646\nvalue = [1146, 8500]'),
#  Text(144.5747310416615, 202.34607645875252, 'X[614494] <= 0.202\ngini = 0.208\nsamples = 9638\nvalue = [1138, 8500]'),
#  Text(144.43033609374305, 202.20024144869214, 'X[482127] <= 0.477\ngini = 0.207\nsamples = 9631\nvalue = [1131, 8500]'),
#  Text(144.2859411458246, 202.0544064386318, 'X[310815] <= 0.183\ngini = 0.206\nsamples = 9624\nvalue = [1124, 8500]'),
#  Text(144.14154619790614, 201.90857142857143, 'X[607481] <= 0.25\ngini = 0.205\nsamples = 9617\nvalue = [1117, 8500]'),
#  Text(143.9971512499877, 201.76273641851105, 'X[538657] <= 0.155\ngini = 0.204\nsamples = 9610\nvalue = [1110, 8500]'),
#  Text(143.85275630206925, 201.6169014084507, 'X[558568] <= 0.257\ngini = 0.203\nsamples = 9603\nvalue = [1103, 8500]'),
#  Text(143.7083613541508, 201.47106639839035, 'X[454419] <= 0.472\ngini = 0.202\nsamples = 9596\nvalue = [1096, 8500]'),
#  Text(142.36368340166024, 201.32523138832997, 'X[408390] <= 0.076\ngini = 0.201\nsamples = 9585\nvalue = [1087, 8498]'),
#  Text(140.90168455398592, 201.17939637826962, 'X[582910] <= 0.279\ngini = 0.197\nsamples = 9470\nvalue = [1049, 8421]'),
#  Text(140.43240097325096, 201.03356136820926, 'X[574099] <= 0.247\ngini = 0.194\nsamples = 9407\nvalue = [1024, 8383]'),
#  Text(140.28800602533252, 200.88772635814888, 'X[209029] <= 0.21\ngini = 0.193\nsamples = 9401\nvalue = [1018, 8383]'),
#  Text(140.14361107741405, 200.74189134808853, 'X[687417] <= 0.243\ngini = 0.192\nsamples = 9395\nvalue = [1012, 8383]'),
#  Text(139.9992161294956, 200.59605633802818, 'X[463376] <= 0.091\ngini = 0.191\nsamples = 9389\nvalue = [1006, 8383]'),
#  Text(139.85482118157717, 200.4502213279678, 'X[568560] <= 0.24\ngini = 0.19\nsamples = 9383\nvalue = [1000, 8383]'),
#  Text(139.71042623365872, 200.30438631790744, 'X[561245] <= 0.148\ngini = 0.19\nsamples = 9377\nvalue = [994, 8383]'),
#  Text(139.56603128574025, 200.1585513078471, 'X[489764] <= 0.213\ngini = 0.189\nsamples = 9371\nvalue = [988, 8383]'),
#  Text(139.4216363378218, 200.0127162977867, 'X[594341] <= 0.086\ngini = 0.188\nsamples = 9365\nvalue = [982, 8383]'),
#  Text(139.27724138990337, 199.86688128772636, 'X[604591] <= 0.142\ngini = 0.187\nsamples = 9359\nvalue = [976, 8383]'),
#  Text(139.1328464419849, 199.721046277666, 'X[650158] <= 0.201\ngini = 0.186\nsamples = 9353\nvalue = [970, 8383]'),
#  Text(138.98845149406645, 199.57521126760562, 'X[559345] <= 0.25\ngini = 0.185\nsamples = 9347\nvalue = [964, 8383]'),
#  Text(138.844056546148, 199.42937625754527, 'X[482267] <= 0.111\ngini = 0.184\nsamples = 9341\nvalue = [958, 8383]'),
#  Text(138.69966159822957, 199.28354124748492, 'X[685713] <= 0.09\ngini = 0.183\nsamples = 9335\nvalue = [952, 8383]'),
#  Text(138.5552666503111, 199.13770623742454, 'X[524932] <= 0.298\ngini = 0.182\nsamples = 9329\nvalue = [946, 8383]'),
#  Text(137.9506128059026, 198.9918712273642, 'X[489762] <= 0.115\ngini = 0.181\nsamples = 9321\nvalue = [939, 8382]'),
#  Text(137.17448996084093, 198.84603621730383, 'X[547122] <= 0.103\ngini = 0.18\nsamples = 9303\nvalue = [928, 8375]'),
#  Text(136.7774038540652, 198.70020120724345, 'X[435506] <= 0.227\ngini = 0.178\nsamples = 9292\nvalue = [920, 8372]'),
#  Text(136.41641648426906, 198.5543661971831, 'X[493083] <= 0.215\ngini = 0.176\nsamples = 9232\nvalue = [898, 8334]'),
#  Text(136.27202153635062, 198.40853118712272, 'X[604253] <= 0.258\ngini = 0.175\nsamples = 9227\nvalue = [893, 8334]'),
#  Text(136.12762658843215, 198.26269617706237, 'X[684483] <= 0.074\ngini = 0.174\nsamples = 9222\nvalue = [888, 8334]'),
#  Text(135.9832316405137, 198.116861167002, 'X[428997] <= 0.125\ngini = 0.173\nsamples = 9217\nvalue = [883, 8334]'),
#  Text(135.83883669259527, 197.97102615694166, 'X[730217] <= 0.482\ngini = 0.172\nsamples = 9212\nvalue = [878, 8334]'),
#  Text(135.69444174467682, 197.82519114688128, 'X[289740] <= 0.181\ngini = 0.172\nsamples = 9207\nvalue = [873, 8334]'),
#  Text(135.55004679675835, 197.67935613682093, 'X[38101] <= 0.098\ngini = 0.171\nsamples = 9202\nvalue = [868, 8334]'),
#  Text(135.4056518488399, 197.53352112676055, 'X[479742] <= 0.11\ngini = 0.17\nsamples = 9197\nvalue = [863, 8334]'),
#  Text(135.26125690092147, 197.3876861167002, 'X[681894] <= 0.247\ngini = 0.169\nsamples = 9192\nvalue = [858, 8334]'),
#  Text(135.11686195300302, 197.24185110663984, 'X[523810] <= 0.246\ngini = 0.168\nsamples = 9187\nvalue = [853, 8334]'),
#  Text(134.97246700508455, 197.0960160965795, 'X[449310] <= 0.208\ngini = 0.168\nsamples = 9182\nvalue = [848, 8334]'),
#  Text(134.8280720571661, 196.9501810865191, 'X[594335] <= 0.413\ngini = 0.167\nsamples = 9177\nvalue = [843, 8334]'),
#  Text(134.68367710924767, 196.80434607645876, 'X[575013] <= 0.253\ngini = 0.166\nsamples = 9172\nvalue = [838, 8334]'),
#  Text(134.5392821613292, 196.65851106639838, 'X[519958] <= 0.266\ngini = 0.165\nsamples = 9167\nvalue = [833, 8334]'),
#  Text(134.39488721341075, 196.51267605633802, 'X[705260] <= 0.157\ngini = 0.164\nsamples = 9162\nvalue = [828, 8334]'),
#  Text(134.2504922654923, 196.36684104627767, 'X[418401] <= 0.357\ngini = 0.164\nsamples = 9157\nvalue = [823, 8334]'),
#  Text(134.10609731757387, 196.2210060362173, 'X[750178] <= 0.101\ngini = 0.163\nsamples = 9152\nvalue = [818, 8334]'),
#  Text(133.348023841002, 196.07517102615694, 'X[509099] <= 0.157\ngini = 0.16\nsamples = 9099\nvalue = [800, 8299]'),
#  Text(133.0592339451651, 195.92933601609658, 'X[715975] <= 0.107\ngini = 0.16\nsamples = 9093\nvalue = [795, 8298]'),
#  Text(132.91483899724665, 195.7835010060362, 'X[693725] <= 0.251\ngini = 0.159\nsamples = 9089\nvalue = [791, 8298]'),
#  Text(132.7704440493282, 195.63766599597585, 'X[315002] <= 0.132\ngini = 0.158\nsamples = 9085\nvalue = [787, 8298]'),
#  Text(132.62604910140973, 195.4918309859155, 'X[574201] <= 0.272\ngini = 0.158\nsamples = 9081\nvalue = [783, 8298]'),
#  Text(132.4816541534913, 195.34599597585512, 'X[670007] <= 0.266\ngini = 0.157\nsamples = 9077\nvalue = [779, 8298]'),
#  Text(132.33725920557285, 195.20016096579477, 'X[596575] <= 0.241\ngini = 0.156\nsamples = 9073\nvalue = [775, 8298]'),
#  Text(132.1928642576544, 195.0543259557344, 'X[711649] <= 0.055\ngini = 0.156\nsamples = 9069\nvalue = [771, 8298]'),
#  Text(131.83187688785827, 194.90849094567403, 'X[405706] <= 0.117\ngini = 0.154\nsamples = 9045\nvalue = [760, 8285]'),
#  Text(131.68748193993983, 194.76265593561368, 'X[519957] <= 0.149\ngini = 0.153\nsamples = 9041\nvalue = [756, 8285]'),
#  Text(131.54308699202136, 194.61682092555333, 'X[37703] <= 0.096\ngini = 0.153\nsamples = 9037\nvalue = [752, 8285]'),
#  Text(131.39869204410292, 194.47098591549295, 'X[445944] <= 0.109\ngini = 0.152\nsamples = 9033\nvalue = [748, 8285]'),
#  Text(131.25429709618447, 194.3251509054326, 'X[529241] <= 0.268\ngini = 0.151\nsamples = 9029\nvalue = [744, 8285]'),
#  Text(131.10990214826603, 194.17931589537224, 'X[712806] <= 0.065\ngini = 0.151\nsamples = 9025\nvalue = [740, 8285]'),
#  Text(130.96550720034756, 194.03348088531186, 'X[145054] <= 0.14\ngini = 0.15\nsamples = 9021\nvalue = [736, 8285]'),
#  Text(130.82111225242912, 193.8876458752515, 'X[754051] <= 0.243\ngini = 0.149\nsamples = 9017\nvalue = [732, 8285]'),
#  Text(130.67671730451067, 193.74181086519116, 'X[476362] <= 0.138\ngini = 0.148\nsamples = 9013\nvalue = [728, 8285]'),
#  Text(130.53232235659223, 193.59597585513077, 'X[677560] <= 0.059\ngini = 0.148\nsamples = 9009\nvalue = [724, 8285]'),
#  Text(129.79229824851015, 193.45014084507042, 'X[573354] <= 0.268\ngini = 0.146\nsamples = 8961\nvalue = [709, 8252]'),
#  Text(129.39521214173442, 193.30430583501007, 'X[721424] <= 0.145\ngini = 0.145\nsamples = 8956\nvalue = [705, 8251]'),
#  Text(129.03422477193828, 193.1584708249497, 'X[746317] <= 0.069\ngini = 0.144\nsamples = 8951\nvalue = [701, 8250]'),
#  Text(128.7454348761014, 193.01263581488934, 'X[553761] <= 0.151\ngini = 0.144\nsamples = 8946\nvalue = [697, 8249]'),
#  Text(128.60103992818296, 192.86680080482898, 'X[746319] <= 0.27\ngini = 0.143\nsamples = 8943\nvalue = [694, 8249]'),
#  Text(128.45664498026449, 192.7209657947686, 'X[625150] <= 0.26\ngini = 0.143\nsamples = 8940\nvalue = [691, 8249]'),
#  Text(128.31225003234604, 192.57513078470825, 'X[590838] <= 0.357\ngini = 0.142\nsamples = 8937\nvalue = [688, 8249]'),
#  Text(128.1678550844276, 192.42929577464787, 'X[225502] <= 0.197\ngini = 0.142\nsamples = 8934\nvalue = [685, 8249]'),
#  Text(128.02346013650916, 192.28346076458752, 'X[569903] <= 0.182\ngini = 0.141\nsamples = 8931\nvalue = [682, 8249]'),
#  Text(127.8790651885907, 192.13762575452716, 'X[718076] <= 0.116\ngini = 0.141\nsamples = 8928\nvalue = [679, 8249]'),
#  Text(127.73467024067224, 191.9917907444668, 'X[590601] <= 0.508\ngini = 0.14\nsamples = 8925\nvalue = [676, 8249]'),
#  Text(127.5902752927538, 191.84595573440643, 'X[203030] <= 0.249\ngini = 0.139\nsamples = 8922\nvalue = [673, 8249]'),
#  Text(127.44588034483534, 191.70012072434608, 'X[708552] <= 0.152\ngini = 0.139\nsamples = 8919\nvalue = [670, 8249]'),
#  Text(127.30148539691689, 191.5542857142857, 'X[643326] <= 0.244\ngini = 0.138\nsamples = 8916\nvalue = [667, 8249]'),
#  Text(127.15709044899845, 191.40845070422534, 'X[212661] <= 0.217\ngini = 0.138\nsamples = 8913\nvalue = [664, 8249]'),
#  Text(127.01269550107999, 191.262615694165, 'X[750182] <= 0.247\ngini = 0.137\nsamples = 8910\nvalue = [661, 8249]'),
#  Text(126.86830055316155, 191.11678068410464, 'X[759649] <= 0.212\ngini = 0.137\nsamples = 8907\nvalue = [658, 8249]'),
#  Text(126.72390560524309, 190.97094567404426, 'X[107917] <= 0.21\ngini = 0.136\nsamples = 8904\nvalue = [655, 8249]'),
#  Text(126.57951065732465, 190.8251106639839, 'X[562247] <= 0.125\ngini = 0.136\nsamples = 8901\nvalue = [652, 8249]'),
#  Text(126.43511570940619, 190.67927565392353, 'X[208973] <= 0.274\ngini = 0.135\nsamples = 8898\nvalue = [649, 8249]'),
#  Text(126.29072076148775, 190.53344064386317, 'X[650985] <= 0.196\ngini = 0.135\nsamples = 8895\nvalue = [646, 8249]'),
#  Text(126.14632581356929, 190.38760563380282, 'X[466974] <= 0.258\ngini = 0.134\nsamples = 8892\nvalue = [643, 8249]'),
#  Text(126.00193086565085, 190.24177062374244, 'X[689672] <= 0.27\ngini = 0.134\nsamples = 8889\nvalue = [640, 8249]'),
#  Text(125.85753591773239, 190.0959356136821, 'X[106976] <= 0.268\ngini = 0.133\nsamples = 8886\nvalue = [637, 8249]'),
#  Text(125.71314096981395, 189.95010060362173, 'X[566086] <= 0.5\ngini = 0.133\nsamples = 8883\nvalue = [634, 8249]'),
#  Text(125.56874602189549, 189.80426559356135, 'X[411303] <= 0.27\ngini = 0.132\nsamples = 8880\nvalue = [631, 8249]'),
#  Text(125.42435107397704, 189.658430583501, 'X[727825] <= 0.23\ngini = 0.131\nsamples = 8877\nvalue = [628, 8249]'),
#  Text(125.2799561260586, 189.51259557344065, 'X[651705] <= 0.363\ngini = 0.131\nsamples = 8874\nvalue = [625, 8249]'),
#  Text(125.13556117814014, 189.36676056338027, 'X[675219] <= 0.278\ngini = 0.13\nsamples = 8871\nvalue = [622, 8249]'),
#  Text(124.9911662302217, 189.22092555331992, 'X[422816] <= 0.261\ngini = 0.13\nsamples = 8868\nvalue = [619, 8249]'),
#  Text(124.84677128230324, 189.07509054325956, 'X[601596] <= 0.256\ngini = 0.129\nsamples = 8865\nvalue = [616, 8249]'),
#  Text(124.7023763343848, 188.92925553319918, 'X[442504] <= 0.264\ngini = 0.129\nsamples = 8862\nvalue = [613, 8249]'),
#  Text(124.55798138646634, 188.78342052313883, 'X[246266] <= 0.124\ngini = 0.128\nsamples = 8859\nvalue = [610, 8249]'),
#  Text(124.4135864385479, 188.63758551307848, 'X[554616] <= 0.09\ngini = 0.128\nsamples = 8856\nvalue = [607, 8249]'),
#  Text(124.26919149062944, 188.4917505030181, 'X[755939] <= 0.235\ngini = 0.127\nsamples = 8853\nvalue = [604, 8249]'),
#  Text(124.124796542711, 188.34591549295774, 'X[540371] <= 0.263\ngini = 0.127\nsamples = 8850\nvalue = [601, 8249]'),
#  Text(123.98040159479254, 188.2000804828974, 'X[724881] <= 0.275\ngini = 0.126\nsamples = 8847\nvalue = [598, 8249]'),
#  Text(123.8360066468741, 188.054245472837, 'X[297877] <= 0.19\ngini = 0.126\nsamples = 8844\nvalue = [595, 8249]'),
#  Text(123.69161169895564, 187.90841046277666, 'X[385584] <= 0.21\ngini = 0.125\nsamples = 8841\nvalue = [592, 8249]'),
#  Text(123.54721675103718, 187.7625754527163, 'X[527915] <= 0.389\ngini = 0.124\nsamples = 8838\nvalue = [589, 8249]'),
#  Text(123.40282180311874, 187.61674044265592, 'X[106209] <= 0.252\ngini = 0.124\nsamples = 8835\nvalue = [586, 8249]'),
#  Text(123.25842685520028, 187.47090543259557, 'X[653809] <= 0.255\ngini = 0.123\nsamples = 8832\nvalue = [583, 8249]'),
#  Text(122.1013988801926, 187.32507042253522, 'X[601399] <= 0.317\ngini = 0.122\nsamples = 8824\nvalue = [578, 8246]'),
#  Text(120.65371261768796, 187.17923541247484, 'X[430756] <= 0.255\ngini = 0.121\nsamples = 8809\nvalue = [571, 8238]'),
#  Text(119.05789462394469, 187.0334004024145, 'X[411302] <= 0.289\ngini = 0.119\nsamples = 8759\nvalue = [557, 8202]'),
#  Text(117.59899801147957, 186.88756539235413, 'X[459569] <= 0.172\ngini = 0.118\nsamples = 8739\nvalue = [549, 8190]'),
#  Text(116.45004289855034, 186.74173038229375, 'X[516539] <= 0.249\ngini = 0.112\nsamples = 8391\nvalue = [502, 7889]'),
#  Text(115.99316825865212, 186.5958953722334, 'X[422578] <= 0.08\ngini = 0.112\nsamples = 8387\nvalue = [499, 7888]'),
#  Text(115.51260382261103, 186.45006036217305, 'X[750745] <= 0.176\ngini = 0.111\nsamples = 8383\nvalue = [496, 7887]'),
#  Text(114.98465979428418, 186.30422535211267, 'X[666490] <= 0.264\ngini = 0.111\nsamples = 8379\nvalue = [493, 7886]'),
#  Text(114.36195658138587, 186.15839034205231, 'X[482126] <= 0.223\ngini = 0.11\nsamples = 8375\nvalue = [490, 7885]'),
#  Text(113.5497349993446, 186.01255533199196, 'X[615810] <= 0.027\ngini = 0.106\nsamples = 8211\nvalue = [463, 7748]'),
#  Text(113.08045141860963, 185.86672032193158, 'X[139388] <= 0.5\ngini = 0.106\nsamples = 8204\nvalue = [459, 7745]'),
#  Text(112.57506910089505, 185.72088531187123, 'X[754130] <= 0.426\ngini = 0.105\nsamples = 8197\nvalue = [455, 7742]'),
#  Text(112.28627920505815, 185.57505030181085, 'X[487462] <= 0.226\ngini = 0.104\nsamples = 8178\nvalue = [448, 7730]'),
#  Text(112.14188425713971, 185.4292152917505, 'X[161704] <= 0.196\ngini = 0.103\nsamples = 8176\nvalue = [446, 7730]'),
#  Text(111.99748930922125, 185.28338028169014, 'X[463795] <= 0.278\ngini = 0.103\nsamples = 8174\nvalue = [444, 7730]'),
#  Text(111.8530943613028, 185.1375452716298, 'X[683644] <= 0.257\ngini = 0.102\nsamples = 8172\nvalue = [442, 7730]'),
#  Text(111.70869941338435, 184.9917102615694, 'X[685840] <= 0.497\ngini = 0.102\nsamples = 8170\nvalue = [440, 7730]'),
#  Text(111.5643044654659, 184.84587525150906, 'X[108388] <= 0.077\ngini = 0.101\nsamples = 8168\nvalue = [438, 7730]'),
#  Text(111.41990951754745, 184.70004024144868, 'X[523830] <= 0.136\ngini = 0.101\nsamples = 8166\nvalue = [436, 7730]'),
#  Text(111.275514569629, 184.55420523138832, 'X[553204] <= 0.126\ngini = 0.101\nsamples = 8164\nvalue = [434, 7730]'),
#  Text(111.13111962171055, 184.40837022132797, 'X[413068] <= 0.257\ngini = 0.1\nsamples = 8162\nvalue = [432, 7730]'),
#  Text(110.9867246737921, 184.26253521126762, 'X[415539] <= 0.249\ngini = 0.1\nsamples = 8160\nvalue = [430, 7730]'),
#  Text(110.84232972587365, 184.11670020120724, 'X[509881] <= 0.272\ngini = 0.099\nsamples = 8158\nvalue = [428, 7730]'),
#  Text(110.6979347779552, 183.97086519114688, 'X[396807] <= 0.243\ngini = 0.099\nsamples = 8156\nvalue = [426, 7730]'),
#  Text(110.55353983003675, 183.8250301810865, 'X[248585] <= 0.159\ngini = 0.099\nsamples = 8154\nvalue = [424, 7730]'),
#  Text(110.4091448821183, 183.67919517102615, 'X[326200] <= 0.077\ngini = 0.098\nsamples = 8152\nvalue = [422, 7730]'),
#  Text(110.26474993419986, 183.5333601609658, 'X[721975] <= 0.18\ngini = 0.098\nsamples = 8150\nvalue = [420, 7730]'),
#  Text(110.1203549862814, 183.38752515090545, 'X[183748] <= 0.132\ngini = 0.097\nsamples = 8148\nvalue = [418, 7730]'),
#  Text(109.97596003836294, 183.24169014084507, 'X[499429] <= 0.278\ngini = 0.097\nsamples = 8146\nvalue = [416, 7730]'),
#  Text(109.8315650904445, 183.0958551307847, 'X[105817] <= 0.283\ngini = 0.097\nsamples = 8144\nvalue = [414, 7730]'),
#  Text(109.68717014252604, 182.95002012072433, 'X[1563] <= 0.221\ngini = 0.096\nsamples = 8142\nvalue = [412, 7730]'),
#  Text(109.5427751946076, 182.80418511066398, 'X[726240] <= 0.283\ngini = 0.096\nsamples = 8140\nvalue = [410, 7730]'),
#  Text(109.39838024668914, 182.65835010060363, 'X[588940] <= 0.275\ngini = 0.095\nsamples = 8138\nvalue = [408, 7730]'),
#  Text(109.2539852987707, 182.51251509054325, 'X[705017] <= 0.123\ngini = 0.095\nsamples = 8136\nvalue = [406, 7730]'),
#  Text(109.10959035085224, 182.3666800804829, 'X[472363] <= 0.087\ngini = 0.094\nsamples = 8134\nvalue = [404, 7730]'),
#  Text(108.9651954029338, 182.22084507042254, 'X[158714] <= 0.219\ngini = 0.094\nsamples = 8132\nvalue = [402, 7730]'),
#  Text(108.82080045501534, 182.07501006036216, 'X[621798] <= 0.132\ngini = 0.094\nsamples = 8130\nvalue = [400, 7730]'),
#  Text(108.6764055070969, 181.9291750503018, 'X[293743] <= 0.216\ngini = 0.093\nsamples = 8128\nvalue = [398, 7730]'),
#  Text(108.53201055917845, 181.78334004024146, 'X[568909] <= 0.27\ngini = 0.093\nsamples = 8126\nvalue = [396, 7730]'),
#  Text(108.38761561126, 181.63750503018107, 'X[660172] <= 0.182\ngini = 0.092\nsamples = 8124\nvalue = [394, 7730]'),
#  Text(108.24322066334155, 181.49167002012072, 'X[142823] <= 0.135\ngini = 0.092\nsamples = 8122\nvalue = [392, 7730]'),
#  Text(108.09882571542309, 181.34583501006037, 'X[627561] <= 0.26\ngini = 0.091\nsamples = 8120\nvalue = [390, 7730]'),
#  Text(107.95443076750465, 181.2, 'X[476634] <= 0.272\ngini = 0.091\nsamples = 8118\nvalue = [388, 7730]'),
#  Text(107.81003581958619, 181.05416498993964, 'X[452995] <= 0.272\ngini = 0.091\nsamples = 8116\nvalue = [386, 7730]'),
#  Text(107.66564087166775, 180.90832997987928, 'X[200700] <= 0.21\ngini = 0.09\nsamples = 8114\nvalue = [384, 7730]'),
#  Text(107.52124592374929, 180.7624949698189, 'X[478698] <= 0.245\ngini = 0.09\nsamples = 8112\nvalue = [382, 7730]'),
#  Text(107.37685097583085, 180.61665995975855, 'X[262809] <= 0.205\ngini = 0.089\nsamples = 8110\nvalue = [380, 7730]'),
#  Text(107.23245602791239, 180.47082494969817, 'X[590840] <= 0.278\ngini = 0.089\nsamples = 8108\nvalue = [378, 7730]'),
#  Text(107.08806107999395, 180.32498993963782, 'X[423062] <= 0.465\ngini = 0.088\nsamples = 8106\nvalue = [376, 7730]'),
#  Text(106.94366613207549, 180.17915492957746, 'X[672415] <= 0.244\ngini = 0.088\nsamples = 8104\nvalue = [374, 7730]'),
#  Text(106.79927118415705, 180.0333199195171, 'X[415717] <= 0.246\ngini = 0.088\nsamples = 8102\nvalue = [372, 7730]'),
#  Text(106.6548762362386, 179.88748490945673, 'X[755292] <= 0.22\ngini = 0.087\nsamples = 8100\nvalue = [370, 7730]'),
#  Text(106.51048128832015, 179.74164989939638, 'X[752941] <= 0.252\ngini = 0.087\nsamples = 8098\nvalue = [368, 7730]'),
#  Text(106.3660863404017, 179.595814889336, 'X[585677] <= 0.283\ngini = 0.086\nsamples = 8096\nvalue = [366, 7730]'),
#  Text(106.22169139248324, 179.44997987927565, 'X[693705] <= 0.327\ngini = 0.086\nsamples = 8094\nvalue = [364, 7730]'),
#  Text(106.0772964445648, 179.3041448692153, 'X[177479] <= 0.286\ngini = 0.085\nsamples = 8092\nvalue = [362, 7730]'),
#  Text(105.93290149664634, 179.15830985915494, 'X[694891] <= 0.078\ngini = 0.085\nsamples = 8090\nvalue = [360, 7730]'),
#  Text(105.7885065487279, 179.01247484909456, 'X[564767] <= 0.275\ngini = 0.085\nsamples = 8088\nvalue = [358, 7730]'),
#  Text(105.64411160080944, 178.8666398390342, 'X[755580] <= 0.17\ngini = 0.084\nsamples = 8086\nvalue = [356, 7730]'),
#  Text(105.499716652891, 178.72080482897383, 'X[649933] <= 0.166\ngini = 0.084\nsamples = 8084\nvalue = [354, 7730]'),
#  Text(105.35532170497254, 178.57496981891347, 'X[623612] <= 0.092\ngini = 0.083\nsamples = 8082\nvalue = [352, 7730]'),
#  Text(105.2109267570541, 178.42913480885312, 'X[516749] <= 0.177\ngini = 0.083\nsamples = 8080\nvalue = [350, 7730]'),
#  Text(105.06653180913564, 178.28329979879277, 'X[565187] <= 0.245\ngini = 0.082\nsamples = 8078\nvalue = [348, 7730]'),
#  Text(104.9221368612172, 178.1374647887324, 'X[325422] <= 0.13\ngini = 0.082\nsamples = 8076\nvalue = [346, 7730]'),
#  Text(104.77774191329874, 177.99162977867203, 'X[721118] <= 0.266\ngini = 0.082\nsamples = 8074\nvalue = [344, 7730]'),
#  Text(104.6333469653803, 177.84579476861165, 'X[412678] <= 0.191\ngini = 0.081\nsamples = 8072\nvalue = [342, 7730]'),
#  Text(104.48895201746184, 177.6999597585513, 'X[594088] <= 0.224\ngini = 0.081\nsamples = 8070\nvalue = [340, 7730]'),
#  Text(104.34455706954338, 177.55412474849095, 'X[614479] <= 0.278\ngini = 0.08\nsamples = 8068\nvalue = [338, 7730]'),
#  Text(104.20016212162494, 177.4082897384306, 'X[410611] <= 0.226\ngini = 0.08\nsamples = 8066\nvalue = [336, 7730]'),
#  Text(104.05576717370649, 177.26245472837022, 'X[607656] <= 0.269\ngini = 0.079\nsamples = 8064\nvalue = [334, 7730]'),
#  Text(103.91137222578804, 177.11661971830986, 'X[742799] <= 0.15\ngini = 0.079\nsamples = 8062\nvalue = [332, 7730]'),
#  Text(103.76697727786959, 176.97078470824948, 'X[220826] <= 0.204\ngini = 0.079\nsamples = 8060\nvalue = [330, 7730]'),
#  Text(103.62258232995114, 176.82494969818913, 'X[609515] <= 0.275\ngini = 0.078\nsamples = 8058\nvalue = [328, 7730]'),
#  Text(103.47818738203269, 176.67911468812878, 'X[122802] <= 0.072\ngini = 0.078\nsamples = 8056\nvalue = [326, 7730]'),
#  Text(102.97195900017016, 176.53327967806842, 'X[476631] <= 0.132\ngini = 0.077\nsamples = 8050\nvalue = [323, 7727]'),
#  Text(102.39268708020043, 176.38744466800804, 'X[428736] <= 0.264\ngini = 0.076\nsamples = 8044\nvalue = [320, 7724]'),
#  Text(101.95611797985325, 176.2416096579477, 'X[628467] <= 0.173\ngini = 0.076\nsamples = 8041\nvalue = [318, 7723]'),
#  Text(101.51616462291422, 176.0957746478873, 'X[496353] <= 0.331\ngini = 0.076\nsamples = 8038\nvalue = [316, 7722]'),
#  Text(101.06944275279152, 175.94993963782696, 'X[698841] <= 0.261\ngini = 0.075\nsamples = 8035\nvalue = [314, 7721]'),
#  Text(100.60918385630146, 175.8041046277666, 'X[571581] <= 0.27\ngini = 0.075\nsamples = 8032\nvalue = [312, 7720]'),
#  Text(100.12185090707668, 175.65826961770622, 'X[704276] <= 0.194\ngini = 0.074\nsamples = 8029\nvalue = [310, 7719]'),
#  Text(99.58036985238249, 175.51243460764587, 'X[442608] <= 0.451\ngini = 0.074\nsamples = 8026\nvalue = [308, 7718]'),
#  Text(98.93059258674947, 175.36659959758552, 'X[598842] <= 0.182\ngini = 0.073\nsamples = 8019\nvalue = [305, 7714]'),
#  Text(98.64180269091257, 175.22076458752514, 'X[559519] <= 0.171\ngini = 0.072\nsamples = 8000\nvalue = [300, 7700]'),
#  Text(98.49740774299411, 175.0749295774648, 'X[526299] <= 0.271\ngini = 0.072\nsamples = 7999\nvalue = [299, 7700]'),
#  Text(98.35301279507567, 174.92909456740443, 'X[507093] <= 0.271\ngini = 0.072\nsamples = 7998\nvalue = [298, 7700]'),
#  Text(98.20861784715721, 174.78325955734405, 'X[675659] <= 0.218\ngini = 0.072\nsamples = 7997\nvalue = [297, 7700]'),
#  Text(98.06422289923877, 174.6374245472837, 'X[674164] <= 0.184\ngini = 0.071\nsamples = 7996\nvalue = [296, 7700]'),
#  Text(97.91982795132031, 174.49158953722335, 'X[204915] <= 0.117\ngini = 0.071\nsamples = 7995\nvalue = [295, 7700]'),
#  Text(97.77543300340187, 174.34575452716297, 'X[514067] <= 0.257\ngini = 0.071\nsamples = 7994\nvalue = [294, 7700]'),
#  Text(97.63103805548342, 174.19991951710261, 'X[561246] <= 0.299\ngini = 0.071\nsamples = 7993\nvalue = [293, 7700]'),
#  Text(97.48664310756497, 174.05408450704226, 'X[407987] <= 0.358\ngini = 0.07\nsamples = 7992\nvalue = [292, 7700]'),
#  Text(97.34224815964652, 173.90824949698188, 'X[418018] <= 0.446\ngini = 0.07\nsamples = 7991\nvalue = [291, 7700]'),
#  Text(97.19785321172806, 173.76241448692153, 'X[758039] <= 0.278\ngini = 0.07\nsamples = 7990\nvalue = [290, 7700]'),
#  Text(97.05345826380962, 173.61657947686115, 'X[616409] <= 0.234\ngini = 0.07\nsamples = 7989\nvalue = [289, 7700]'),
#  Text(96.90906331589116, 173.4707444668008, 'X[531797] <= 0.144\ngini = 0.07\nsamples = 7988\nvalue = [288, 7700]'),
#  Text(96.76466836797272, 173.32490945674044, 'X[701203] <= 0.19\ngini = 0.069\nsamples = 7987\nvalue = [287, 7700]'),
#  Text(96.62027342005426, 173.1790744466801, 'X[482716] <= 0.205\ngini = 0.069\nsamples = 7986\nvalue = [286, 7700]'),
#  Text(96.47587847213582, 173.0332394366197, 'X[505175] <= 0.281\ngini = 0.069\nsamples = 7985\nvalue = [285, 7700]'),
#  Text(96.33148352421736, 172.88740442655936, 'X[418006] <= 0.226\ngini = 0.069\nsamples = 7984\nvalue = [284, 7700]'),
#  Text(96.18708857629892, 172.74156941649898, 'X[729374] <= 0.227\ngini = 0.068\nsamples = 7983\nvalue = [283, 7700]'),
#  Text(96.04269362838046, 172.59573440643862, 'X[468949] <= 0.167\ngini = 0.068\nsamples = 7982\nvalue = [282, 7700]'),
#  Text(95.89829868046202, 172.44989939637827, 'X[628660] <= 0.212\ngini = 0.068\nsamples = 7981\nvalue = [281, 7700]'),
#  Text(95.75390373254356, 172.30406438631792, 'X[134760] <= 0.312\ngini = 0.068\nsamples = 7980\nvalue = [280, 7700]'),
#  Text(95.60950878462512, 172.15822937625754, 'X[490822] <= 0.118\ngini = 0.067\nsamples = 7979\nvalue = [279, 7700]'),
#  Text(95.46511383670666, 172.01239436619719, 'X[313763] <= 0.277\ngini = 0.067\nsamples = 7978\nvalue = [278, 7700]'),
#  Text(95.3207188887882, 171.8665593561368, 'X[182285] <= 0.22\ngini = 0.067\nsamples = 7977\nvalue = [277, 7700]'),
#  Text(95.17632394086976, 171.72072434607645, 'X[699926] <= 0.157\ngini = 0.067\nsamples = 7976\nvalue = [276, 7700]'),
#  Text(95.03192899295131, 171.5748893360161, 'X[134943] <= 0.486\ngini = 0.067\nsamples = 7975\nvalue = [275, 7700]'),
#  Text(94.88753404503287, 171.42905432595575, 'X[213671] <= 0.298\ngini = 0.066\nsamples = 7974\nvalue = [274, 7700]'),
#  Text(94.74313909711441, 171.28321931589537, 'X[302840] <= 0.294\ngini = 0.066\nsamples = 7973\nvalue = [273, 7700]'),
#  Text(94.59874414919597, 171.137384305835, 'X[527963] <= 0.162\ngini = 0.066\nsamples = 7972\nvalue = [272, 7700]'),
#  Text(94.45434920127751, 170.99154929577463, 'X[641797] <= 0.188\ngini = 0.066\nsamples = 7971\nvalue = [271, 7700]'),
#  Text(94.30995425335907, 170.84571428571428, 'X[176449] <= 0.299\ngini = 0.065\nsamples = 7970\nvalue = [270, 7700]'),
#  Text(94.16555930544061, 170.69987927565393, 'X[514437] <= 0.309\ngini = 0.065\nsamples = 7969\nvalue = [269, 7700]'),
#  Text(94.02116435752217, 170.55404426559357, 'X[94276] <= 0.239\ngini = 0.065\nsamples = 7968\nvalue = [268, 7700]'),
#  Text(93.87676940960371, 170.4082092555332, 'X[721959] <= 0.176\ngini = 0.065\nsamples = 7967\nvalue = [267, 7700]'),
#  Text(93.73237446168525, 170.26237424547284, 'X[192946] <= 0.242\ngini = 0.065\nsamples = 7966\nvalue = [266, 7700]'),
#  Text(93.58797951376681, 170.11653923541246, 'X[354344] <= 0.214\ngini = 0.064\nsamples = 7965\nvalue = [265, 7700]'),
#  Text(93.44358456584835, 169.9707042253521, 'X[506235] <= 0.415\ngini = 0.064\nsamples = 7964\nvalue = [264, 7700]'),
#  Text(93.29918961792991, 169.82486921529176, 'X[637729] <= 0.185\ngini = 0.064\nsamples = 7963\nvalue = [263, 7700]'),
#  Text(93.15479467001146, 169.6790342052314, 'X[220740] <= 0.501\ngini = 0.064\nsamples = 7962\nvalue = [262, 7700]'),
#  Text(93.01039972209301, 169.53319919517102, 'X[681186] <= 0.279\ngini = 0.063\nsamples = 7961\nvalue = [261, 7700]'),
#  Text(92.86600477417456, 169.38736418511067, 'X[411717] <= 0.266\ngini = 0.063\nsamples = 7960\nvalue = [260, 7700]'),
#  Text(92.72160982625611, 169.2415291750503, 'X[244387] <= 0.229\ngini = 0.063\nsamples = 7959\nvalue = [259, 7700]'),
#  Text(92.57721487833766, 169.09569416498994, 'X[444960] <= 0.11\ngini = 0.063\nsamples = 7958\nvalue = [258, 7700]'),
#  Text(92.43281993041921, 168.94985915492958, 'X[266066] <= 0.248\ngini = 0.063\nsamples = 7957\nvalue = [257, 7700]'),
#  Text(92.28842498250076, 168.8040241448692, 'X[729494] <= 0.279\ngini = 0.062\nsamples = 7956\nvalue = [256, 7700]'),
#  Text(92.14403003458231, 168.65818913480885, 'X[681994] <= 0.444\ngini = 0.062\nsamples = 7955\nvalue = [255, 7700]'),
#  Text(91.99963508666386, 168.5123541247485, 'X[235590] <= 0.273\ngini = 0.062\nsamples = 7954\nvalue = [254, 7700]'),
#  Text(91.8552401387454, 168.36651911468812, 'X[270442] <= 0.285\ngini = 0.062\nsamples = 7953\nvalue = [253, 7700]'),
#  Text(91.71084519082696, 168.22068410462776, 'X[427322] <= 0.155\ngini = 0.061\nsamples = 7952\nvalue = [252, 7700]'),
#  Text(91.5664502429085, 168.0748490945674, 'X[245600] <= 0.277\ngini = 0.061\nsamples = 7951\nvalue = [251, 7700]'),
#  Text(91.42205529499006, 167.92901408450703, 'X[529564] <= 0.237\ngini = 0.061\nsamples = 7950\nvalue = [250, 7700]'),
#  Text(91.2776603470716, 167.78317907444668, 'X[182479] <= 0.3\ngini = 0.061\nsamples = 7949\nvalue = [249, 7700]'),
#  Text(91.13326539915316, 167.6373440643863, 'X[705294] <= 0.241\ngini = 0.06\nsamples = 7948\nvalue = [248, 7700]'),
#  Text(90.9888704512347, 167.49150905432595, 'X[131444] <= 0.294\ngini = 0.06\nsamples = 7947\nvalue = [247, 7700]'),
#  Text(90.84447550331626, 167.3456740442656, 'X[235861] <= 0.275\ngini = 0.06\nsamples = 7946\nvalue = [246, 7700]'),
#  Text(90.7000805553978, 167.19983903420524, 'X[457184] <= 0.189\ngini = 0.06\nsamples = 7945\nvalue = [245, 7700]'),
#  Text(90.55568560747936, 167.05400402414486, 'X[361324] <= 0.294\ngini = 0.06\nsamples = 7944\nvalue = [244, 7700]'),
#  Text(90.4112906595609, 166.9081690140845, 'X[224930] <= 0.269\ngini = 0.059\nsamples = 7943\nvalue = [243, 7700]'),
#  Text(90.26689571164246, 166.76233400402413, 'X[227154] <= 0.232\ngini = 0.059\nsamples = 7942\nvalue = [242, 7700]'),
#  Text(90.122500763724, 166.61649899396377, 'X[482038] <= 0.195\ngini = 0.059\nsamples = 7941\nvalue = [241, 7700]'),
#  Text(89.97810581580555, 166.47066398390342, 'X[680487] <= 0.2\ngini = 0.059\nsamples = 7940\nvalue = [240, 7700]'),
#  Text(89.8337108678871, 166.32482897384307, 'X[380304] <= 0.224\ngini = 0.058\nsamples = 7939\nvalue = [239, 7700]'),
#  Text(89.68931591996865, 166.1789939637827, 'X[638608] <= 0.19\ngini = 0.058\nsamples = 7938\nvalue = [238, 7700]'),
#  Text(89.5449209720502, 166.03315895372234, 'X[691932] <= 0.163\ngini = 0.058\nsamples = 7937\nvalue = [237, 7700]'),
#  Text(89.40052602413175, 165.88732394366195, 'X[339578] <= 0.314\ngini = 0.058\nsamples = 7936\nvalue = [236, 7700]'),
#  Text(89.25613107621331, 165.7414889336016, 'X[296691] <= 0.307\ngini = 0.057\nsamples = 7935\nvalue = [235, 7700]'),
#  Text(89.11173612829485, 165.59565392354125, 'X[136589] <= 0.318\ngini = 0.057\nsamples = 7934\nvalue = [234, 7700]'),
#  Text(88.96734118037641, 165.4498189134809, 'X[633812] <= 0.215\ngini = 0.057\nsamples = 7933\nvalue = [233, 7700]'),
#  Text(88.82294623245795, 165.30398390342052, 'X[750177] <= 0.187\ngini = 0.057\nsamples = 7932\nvalue = [232, 7700]'),
#  Text(88.67855128453951, 165.15814889336016, 'X[450210] <= 0.239\ngini = 0.057\nsamples = 7931\nvalue = [231, 7700]'),
#  Text(88.53415633662105, 165.01231388329978, 'X[464759] <= 0.17\ngini = 0.056\nsamples = 7930\nvalue = [230, 7700]'),
#  Text(88.38976138870261, 164.86647887323943, 'X[102890] <= 0.239\ngini = 0.056\nsamples = 7929\nvalue = [229, 7700]'),
#  Text(88.24536644078415, 164.72064386317908, 'X[585838] <= 0.24\ngini = 0.056\nsamples = 7928\nvalue = [228, 7700]'),
#  Text(88.1009714928657, 164.57480885311872, 'X[148352] <= 0.3\ngini = 0.056\nsamples = 7927\nvalue = [227, 7700]'),
#  Text(87.95657654494725, 164.42897384305834, 'X[246083] <= 0.193\ngini = 0.055\nsamples = 7926\nvalue = [226, 7700]'),
#  Text(87.8121815970288, 164.283138832998, 'X[150077] <= 0.256\ngini = 0.055\nsamples = 7925\nvalue = [225, 7700]'),
#  Text(87.66778664911035, 164.1373038229376, 'X[182783] <= 0.288\ngini = 0.055\nsamples = 7924\nvalue = [224, 7700]'),
#  Text(87.5233917011919, 163.99146881287726, 'X[448225] <= 0.216\ngini = 0.055\nsamples = 7923\nvalue = [223, 7700]'),
#  Text(87.37899675327346, 163.8456338028169, 'X[711781] <= 0.25\ngini = 0.054\nsamples = 7922\nvalue = [222, 7700]'),
#  Text(87.234601805355, 163.69979879275655, 'X[118532] <= 0.201\ngini = 0.054\nsamples = 7921\nvalue = [221, 7700]'),
#  Text(87.09020685743656, 163.55396378269617, 'X[577086] <= 0.292\ngini = 0.054\nsamples = 7920\nvalue = [220, 7700]'),
#  Text(86.9458119095181, 163.40812877263582, 'X[509944] <= 0.211\ngini = 0.054\nsamples = 7919\nvalue = [219, 7700]'),
#  Text(86.80141696159966, 163.26229376257544, 'X[420463] <= 0.108\ngini = 0.054\nsamples = 7918\nvalue = [218, 7700]'),
#  Text(86.6570220136812, 163.1164587525151, 'X[617647] <= 0.336\ngini = 0.053\nsamples = 7917\nvalue = [217, 7700]'),
#  Text(86.51262706576276, 162.97062374245473, 'X[231321] <= 0.209\ngini = 0.053\nsamples = 7916\nvalue = [216, 7700]'),
#  Text(86.3682321178443, 162.82478873239435, 'X[301047] <= 0.273\ngini = 0.053\nsamples = 7915\nvalue = [215, 7700]'),
#  Text(86.22383716992584, 162.678953722334, 'X[727411] <= 0.273\ngini = 0.053\nsamples = 7914\nvalue = [214, 7700]'),
#  Text(86.0794422220074, 162.53311871227365, 'X[578845] <= 0.15\ngini = 0.052\nsamples = 7913\nvalue = [213, 7700]'),
#  Text(85.93504727408894, 162.38728370221327, 'X[223013] <= 0.3\ngini = 0.052\nsamples = 7912\nvalue = [212, 7700]'),
#  Text(85.7906523261705, 162.24144869215291, 'X[6110] <= 0.175\ngini = 0.052\nsamples = 7911\nvalue = [211, 7700]'),
#  Text(85.64625737825205, 162.09561368209256, 'X[404647] <= 0.262\ngini = 0.052\nsamples = 7910\nvalue = [210, 7700]'),
#  Text(85.5018624303336, 161.94977867203218, 'X[591628] <= 0.234\ngini = 0.051\nsamples = 7909\nvalue = [209, 7700]'),
#  Text(85.35746748241515, 161.80394366197183, 'X[609650] <= 0.285\ngini = 0.051\nsamples = 7908\nvalue = [208, 7700]'),
#  Text(85.2130725344967, 161.65810865191148, 'X[715581] <= 0.279\ngini = 0.051\nsamples = 7907\nvalue = [207, 7700]'),
#  Text(85.06867758657825, 161.5122736418511, 'X[532027] <= 0.215\ngini = 0.051\nsamples = 7906\nvalue = [206, 7700]'),
#  Text(84.9242826386598, 161.36643863179074, 'X[651648] <= 0.181\ngini = 0.051\nsamples = 7905\nvalue = [205, 7700]'),
#  Text(84.77988769074135, 161.2206036217304, 'X[226857] <= 0.224\ngini = 0.05\nsamples = 7904\nvalue = [204, 7700]'),
#  Text(84.6354927428229, 161.07476861167, 'X[414973] <= 0.232\ngini = 0.05\nsamples = 7903\nvalue = [203, 7700]'),
#  Text(84.49109779490445, 160.92893360160966, 'X[722937] <= 0.244\ngini = 0.05\nsamples = 7902\nvalue = [202, 7700]'),
#  Text(84.34670284698599, 160.78309859154928, 'X[437196] <= 0.286\ngini = 0.05\nsamples = 7901\nvalue = [201, 7700]'),
#  Text(84.20230789906755, 160.63726358148892, 'X[142986] <= 0.276\ngini = 0.049\nsamples = 7900\nvalue = [200, 7700]'),
#  Text(84.05791295114909, 160.49142857142857, 'X[486605] <= 0.133\ngini = 0.049\nsamples = 7899\nvalue = [199, 7700]'),
#  Text(83.91351800323065, 160.34559356136822, 'X[387054] <= 0.213\ngini = 0.049\nsamples = 7898\nvalue = [198, 7700]'),
#  Text(83.76912305531219, 160.19975855130784, 'X[422207] <= 0.241\ngini = 0.049\nsamples = 7897\nvalue = [197, 7700]'),
#  Text(83.62472810739375, 160.05392354124749, 'X[273488] <= 0.16\ngini = 0.048\nsamples = 7896\nvalue = [196, 7700]'),
#  Text(83.4803331594753, 159.9080885311871, 'X[140452] <= 0.213\ngini = 0.048\nsamples = 7895\nvalue = [195, 7700]'),
#  Text(83.33593821155685, 159.76225352112675, 'X[177081] <= 0.209\ngini = 0.048\nsamples = 7894\nvalue = [194, 7700]'),
#  Text(83.1915432636384, 159.6164185110664, 'X[428823] <= 0.231\ngini = 0.048\nsamples = 7893\nvalue = [193, 7700]'),
#  Text(83.04714831571995, 159.47058350100605, 'X[240652] <= 0.209\ngini = 0.047\nsamples = 7892\nvalue = [192, 7700]'),
#  Text(82.9027533678015, 159.32474849094567, 'X[163960] <= 0.312\ngini = 0.047\nsamples = 7891\nvalue = [191, 7700]'),
#  Text(82.75835841988305, 159.1789134808853, 'X[146996] <= 0.272\ngini = 0.047\nsamples = 7890\nvalue = [190, 7700]'),
#  Text(82.6139634719646, 159.03307847082493, 'X[147629] <= 0.305\ngini = 0.047\nsamples = 7889\nvalue = [189, 7700]'),
#  Text(82.46956852404614, 158.88724346076458, 'X[407890] <= 0.147\ngini = 0.047\nsamples = 7888\nvalue = [188, 7700]'),
# ...
#  Text(89.68931591996865, 165.88732394366195, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(89.8337108678871, 166.03315895372234, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(89.97810581580555, 166.1789939637827, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(90.122500763724, 166.32482897384307, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(90.26689571164246, 166.47066398390342, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(90.4112906595609, 166.61649899396377, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(90.55568560747936, 166.76233400402413, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(90.7000805553978, 166.9081690140845, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(90.84447550331626, 167.05400402414486, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(90.9888704512347, 167.19983903420524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(91.13326539915316, 167.3456740442656, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(91.2776603470716, 167.49150905432595, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(91.42205529499006, 167.6373440643863, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(91.5664502429085, 167.78317907444668, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(91.71084519082696, 167.92901408450703, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(91.8552401387454, 168.0748490945674, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(91.99963508666386, 168.22068410462776, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(92.14403003458231, 168.36651911468812, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(92.28842498250076, 168.5123541247485, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(92.43281993041921, 168.65818913480885, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(92.57721487833766, 168.8040241448692, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(92.72160982625611, 168.94985915492958, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(92.86600477417456, 169.09569416498994, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(93.01039972209301, 169.2415291750503, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(93.15479467001146, 169.38736418511067, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(93.29918961792991, 169.53319919517102, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(93.44358456584835, 169.6790342052314, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(93.58797951376681, 169.82486921529176, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(93.73237446168525, 169.9707042253521, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(93.87676940960371, 170.11653923541246, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(94.02116435752217, 170.26237424547284, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(94.16555930544061, 170.4082092555332, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(94.30995425335907, 170.55404426559357, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(94.45434920127751, 170.69987927565393, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(94.59874414919597, 170.84571428571428, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(94.74313909711441, 170.99154929577463, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(94.88753404503287, 171.137384305835, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(95.03192899295131, 171.28321931589537, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(95.17632394086976, 171.42905432595575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(95.3207188887882, 171.5748893360161, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(95.46511383670666, 171.72072434607645, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(95.60950878462512, 171.8665593561368, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(95.75390373254356, 172.01239436619719, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(95.89829868046202, 172.15822937625754, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(96.04269362838046, 172.30406438631792, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(96.18708857629892, 172.44989939637827, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(96.33148352421736, 172.59573440643862, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(96.47587847213582, 172.74156941649898, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(96.62027342005426, 172.88740442655936, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(96.76466836797272, 173.0332394366197, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(96.90906331589116, 173.1790744466801, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(97.05345826380962, 173.32490945674044, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(97.19785321172806, 173.4707444668008, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(97.34224815964652, 173.61657947686115, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(97.48664310756497, 173.76241448692153, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(97.63103805548342, 173.90824949698188, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(97.77543300340187, 174.05408450704226, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(97.91982795132031, 174.19991951710261, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(98.06422289923877, 174.34575452716297, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(98.20861784715721, 174.49158953722335, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(98.35301279507567, 174.6374245472837, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(98.49740774299411, 174.78325955734405, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(98.64180269091257, 174.92909456740443, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(98.78619763883101, 175.0749295774648, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(99.21938248258637, 175.22076458752514, 'X[598842] <= 0.186\ngini = 0.388\nsamples = 19\nvalue = [5, 14]'),
#  Text(99.07498753466791, 175.0749295774648, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(99.36377743050483, 175.0749295774648, 'X[336077] <= 0.264\ngini = 0.291\nsamples = 17\nvalue = [3, 14]'),
#  Text(99.21938248258637, 174.92909456740443, 'X[721461] <= 0.236\ngini = 0.219\nsamples = 16\nvalue = [2, 14]'),
#  Text(99.07498753466791, 174.78325955734405, 'X[97043] <= 0.286\ngini = 0.124\nsamples = 15\nvalue = [1, 14]'),
#  Text(98.93059258674947, 174.6374245472837, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(99.21938248258637, 174.6374245472837, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(99.36377743050483, 174.78325955734405, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(99.50817237842327, 174.92909456740443, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(100.23014711801552, 175.36659959758552, 'X[152213] <= 0.309\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(100.08575217009707, 175.22076458752514, 'X[202214] <= 0.309\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(99.94135722217862, 175.0749295774648, 'X[271500] <= 0.309\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(99.79696227426017, 174.92909456740443, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(100.08575217009707, 174.92909456740443, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(100.23014711801552, 175.0749295774648, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(100.37454206593397, 175.22076458752514, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(100.66333196177087, 175.51243460764587, 'X[237919] <= 0.251\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(100.51893701385242, 175.36659959758552, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(100.80772690968932, 175.36659959758552, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(101.09651680552622, 175.65826961770622, 'X[134768] <= 0.298\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(100.95212185760776, 175.51243460764587, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(101.24091175344468, 175.51243460764587, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(101.52970164928158, 175.8041046277666, 'X[237398] <= 0.305\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(101.38530670136312, 175.65826961770622, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(101.67409659720002, 175.65826961770622, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(101.96288649303692, 175.94993963782696, 'X[196468] <= 0.311\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(101.81849154511848, 175.8041046277666, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(102.10728144095538, 175.8041046277666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(102.39607133679228, 176.0957746478873, 'X[471707] <= 0.152\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(102.25167638887382, 175.94993963782696, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(102.54046628471072, 175.94993963782696, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(102.82925618054762, 176.2416096579477, 'X[174775] <= 0.29\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(102.68486123262917, 176.0957746478873, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(102.97365112846607, 176.0957746478873, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(103.55123092013987, 176.38744466800804, 'X[451048] <= 0.123\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(103.40683597222143, 176.2416096579477, 'X[656333] <= 0.138\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(103.26244102430297, 176.0957746478873, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(103.55123092013987, 176.0957746478873, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(103.69562586805833, 176.2416096579477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(103.98441576389523, 176.53327967806842, 'X[122802] <= 0.17\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(103.84002081597677, 176.38744466800804, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(104.12881071181367, 176.38744466800804, 'X[414995] <= 0.123\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(103.98441576389523, 176.2416096579477, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(104.27320565973213, 176.2416096579477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(103.76697727786959, 176.67911468812878, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(103.91137222578804, 176.82494969818913, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(104.05576717370649, 176.97078470824948, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(104.20016212162494, 177.11661971830986, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(104.34455706954338, 177.26245472837022, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(104.48895201746184, 177.4082897384306, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(104.6333469653803, 177.55412474849095, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(104.77774191329874, 177.6999597585513, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(104.9221368612172, 177.84579476861165, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(105.06653180913564, 177.99162977867203, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(105.2109267570541, 178.1374647887324, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(105.35532170497254, 178.28329979879277, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(105.499716652891, 178.42913480885312, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(105.64411160080944, 178.57496981891347, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(105.7885065487279, 178.72080482897383, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(105.93290149664634, 178.8666398390342, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(106.0772964445648, 179.01247484909456, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(106.22169139248324, 179.15830985915494, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(106.3660863404017, 179.3041448692153, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(106.51048128832015, 179.44997987927565, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(106.6548762362386, 179.595814889336, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(106.79927118415705, 179.74164989939638, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(106.94366613207549, 179.88748490945673, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(107.08806107999395, 180.0333199195171, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(107.23245602791239, 180.17915492957746, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(107.37685097583085, 180.32498993963782, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(107.52124592374929, 180.47082494969817, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(107.66564087166775, 180.61665995975855, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(107.81003581958619, 180.7624949698189, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(107.95443076750465, 180.90832997987928, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(108.09882571542309, 181.05416498993964, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(108.24322066334155, 181.2, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(108.38761561126, 181.34583501006037, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(108.53201055917845, 181.49167002012072, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(108.6764055070969, 181.63750503018107, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(108.82080045501534, 181.78334004024146, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(108.9651954029338, 181.9291750503018, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(109.10959035085224, 182.07501006036216, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(109.2539852987707, 182.22084507042254, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(109.39838024668914, 182.3666800804829, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(109.5427751946076, 182.51251509054325, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(109.68717014252604, 182.65835010060363, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(109.8315650904445, 182.80418511066398, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(109.97596003836294, 182.95002012072433, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(110.1203549862814, 183.0958551307847, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(110.26474993419986, 183.24169014084507, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(110.4091448821183, 183.38752515090545, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(110.55353983003675, 183.5333601609658, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(110.6979347779552, 183.67919517102615, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(110.84232972587365, 183.8250301810865, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(110.9867246737921, 183.97086519114688, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(111.13111962171055, 184.11670020120724, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(111.275514569629, 184.26253521126762, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(111.41990951754745, 184.40837022132797, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(111.5643044654659, 184.55420523138832, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(111.70869941338435, 184.70004024144868, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(111.8530943613028, 184.84587525150906, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(111.99748930922125, 184.9917102615694, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(112.14188425713971, 185.1375452716298, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(112.28627920505815, 185.28338028169014, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(112.43067415297661, 185.4292152917505, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(112.86385899673195, 185.57505030181085, 'X[754130] <= 0.49\ngini = 0.465\nsamples = 19\nvalue = [7, 12]'),
#  Text(112.7194640488135, 185.4292152917505, 'X[357185] <= 0.309\ngini = 0.5\nsamples = 14\nvalue = [7, 7]'),
#  Text(112.57506910089505, 185.28338028169014, 'X[342119] <= 0.309\ngini = 0.497\nsamples = 13\nvalue = [7, 6]'),
#  Text(112.43067415297661, 185.1375452716298, 'X[129157] <= 0.304\ngini = 0.486\nsamples = 12\nvalue = [7, 5]'),
#  Text(112.28627920505815, 184.9917102615694, 'X[391666] <= 0.309\ngini = 0.463\nsamples = 11\nvalue = [7, 4]'),
#  ...]
